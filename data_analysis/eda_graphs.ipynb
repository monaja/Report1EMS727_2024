# %%
import pandas as pd

import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('data_samples/DATA2000csv.csv')

data.info()

plt.hist(data['20.00cm'], bins=30, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 20.00cm 20 Data')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   20.00cm  200 non-null    int64
# dtypes: int64(1)
# memory usage: 1.7 KB

# %%
data.std()
# Out:
# 20.00cm    2.142745
# dtype: float64

# %%
data.mean()
# Out:
# 20.00cm    1149.96
# dtype: float64

# %%
import numpy as np

# Define the row data
x = np.array([2, 5, 10, 25, 30, 40, 50, 70, 80, 88])
y1 = np.array([117.17, 241.44, 608.29, 1378.11, 1680.65, 2212.12, 2801.70, 3896.23, 4470.27, 4358.63])
y2 = np.array([211.70, 1878.48, 1878.48, 3263.50, 4160.78, 6117.49, 4377.82, 4038.19, 4636.97, 5260.19])
y3 = np.array([116.61, 291.55, 583.10, 1457.87, 1750.44, 2333.95, 2917.48, 4084.87, 4668.38, 5135.64])

# Plot y3
plt.plot(x, y3, label='Expected', marker='o')
print("x:", x)
print("y1:", y1)
print("y2:", y2)

plt.figure(figsize=(10, 6))

# Plot y1
plt.plot(x, y1, label='0 degress', marker='o')

# Plot y2
plt.plot(x, y2, label='45 degres', marker='o')
plt.plot(x, y3, label='Expected', marker='o')

# Add labels and title
plt.xlabel('Distance in (cm)')
plt.ylabel('Time in Microseconds')
plt.title('Comparison of 0 and 45 degress inclination and expected')

# Add legend
plt.legend()

# Show the plot
plt.show()

angles1 = np.array([0, 36, 72, 108, 144, 180, 216, 252, 288, 324, 360, 396, 432, 468, 504, 540, 576, 612, 648, 684, 720])
readings1 = np.array([15945.6, 12254.6, 5004.6, -6565.4, -14805.2, -17755.4, -14886.2, -6675.8, 3959.8, 12554, 15654.8, 12207, 3576.8, -6712, -14890.6, -17522.0, -13962.4, -6364, 3862, 12296.2, 15918.2])
  
plt.figure(figsize=(10, 6))

# Plot readings1
plt.plot(angles1, readings1, label='0-370 degrees', marker='o')
 

# Add labels and title
plt.xlabel('Angle (degrees)')
plt.ylabel('Accelerometer reading')
plt.title('Accelerometer readings at different angles')

# Add legend
plt.legend()

# Show the plot
plt.show()

max_reading1 = np.max(readings1)
min_reading1 = np.min(readings1)
 

print("Maximum reading1:", max_reading1)
print("Minimum reading1:", min_reading1)
print("Maximum reading2:", max_reading2)
print("Minimum reading2:", min_reading2)
# Out:
# x: [ 2  5 10 25 30 40 50 70 80 88]
# y1: [ 117.17  241.44  608.29 1378.11 1680.65 2212.12 2801.7  3896.23 4470.27
#  4358.63]
# y2: [ 211.7  1878.48 1878.48 3263.5  4160.78 6117.49 4377.82 4038.19 4636.97
#  5260.19]
# Maximum reading1: 15945.6
# Minimum reading1: -17755.4
# Maximum reading2: 15918.2
# Minimum reading2: -17522.0

# %%
max_reading1 = np.max(readings1)
min_reading1 = np.min(readings1)

max_reading2 = np.max(readings2)
min_reading2 = np.min(readings2)

print("Maximum reading1:", max_reading1)
print("Minimum reading1:", min_reading1)
print("Maximum reading2:", max_reading2)
print("Minimum reading2:", min_reading2)
